# %%
import numpy as np
import pandas as pd
import spacy

# Load spaCy for french
spacy_nlp = spacy.load("fr_core_news_sm")

# %%
X_train = pd.read_csv('data/X_train.csv')
Y_train = pd.read_csv('data/Y_train.csv')

# %%
X_train.head()
# Out:
#    Unnamed: 0                                        designation  \
# 0           0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1           1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2           2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3           3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4           4                               La Guerre Des Tuques
#
#                                          description   productid     imageid
# 0                                                NaN  3804725264  1263597046
# 1                                                NaN   436067568  1008141237
# 2  PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                NaN    50418756   457047496
# 4  Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786

# %% [markdown]
# ## Pre-processing
#
# 1. We only keep the designation and id.
# 2. We normalize the accents
# 3. We tokenise the text extracts

# %%
# designation and ids
def cleaning(X_train): 
    X_train = X_train.drop(['description', 'productid','imageid'], axis=1)
    X_train.columns = ['integer_id', 'designation']
    return X_train

# %%
X_train = cleaning(X_train)

# %%
X_train
# Out:
#        integer_id                                        designation
# 0               0  Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1               1  Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2               2  Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3               3  Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4               4                               La Guerre Des Tuques
# ...           ...                                                ...
# 84911       84911                        The Sims [ Import Anglais ]
# 84912       84912  Kit piscine acier NEVADA déco pierre Ø 3.50m x...
# 84913       84913  Journal Officiel De La Republique Francaise N°...
# 84914       84914  Table Basse Bois De Récupération Massif Base B...
# 84915       84915  Gomme De Collection 2 Gommes Pinguin Glace Ver...
#
# [84916 rows x 2 columns]

# %%
def normalize_accent(string):
    string = string.replace('á', 'a')
    string = string.replace('â', 'a')

    string = string.replace('é', 'e')
    string = string.replace('è', 'e')
    string = string.replace('ê', 'e')
    string = string.replace('ë', 'e')

    string = string.replace('î', 'i')
    string = string.replace('ï', 'i')

    string = string.replace('ö', 'o')
    string = string.replace('ô', 'o')
    string = string.replace('ò', 'o')
    string = string.replace('ó', 'o')

    string = string.replace('ù', 'u')
    string = string.replace('û', 'u')
    string = string.replace('ü', 'u')

    string = string.replace('ç', 'c')
    
    return string

# %%
def raw_to_tokens(raw_string, spacy_nlp):
    # Write code for lower-casing
    string = raw_string.lower()
    
    # Write code to normalize the accents
    string = normalize_accent(string)
        
    # Write code to tokenize
    spacy_tokens = spacy_nlp(string)
        
    # Write code to remove punctuation tokens and create string tokens
    string_tokens = [token.orth_ for token in spacy_tokens if not token.is_punct if not token.is_stop]
    
    # Write code to join the tokens back into a single string
    clean_string = " ".join(string_tokens)
    
    return clean_string

# %%
print("Raw string: ", X_train['designation'][26])

# Call the above raw_to_tokens function
clean_2 = raw_to_tokens(X_train['designation'][26] ,spacy_nlp)

print("Clean string: ", clean_2)
# Out:
# Raw string:  Modèle De Voiture 4pcs Alliage Métallique 1.9in Jante De Roue Pour 1/10 Traxxas Trx4 Hsp Scx10 D90 Rc Voiture
# Clean string:  modele voiture 4pcs alliage metallique 1.9 in jante roue 1/10 traxxas trx4 hsp scx10 d90 rc voiture

# %%
X_train['designation_cleaned'] = X_train['designation']
for i in range(84916) : 
    if i % 100 == 0 :
        print(i,"is done")
    X_train['designation_cleaned'][i] = raw_to_tokens(X_train['designation'][i] ,spacy_nlp)
# Out:
# 0 is done
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 100 is done
# 200 is done
# 300 is done
# 400 is done
# 500 is done
# 600 is done
# 700 is done
# 800 is done
# 900 is done
# 1000 is done
# 1100 is done
# 1200 is done
# 1300 is done
# 1400 is done
# 1500 is done
# 1600 is done
# 1700 is done
# 1800 is done
# 1900 is done
# 2000 is done
# 2100 is done
# 2200 is done
# 2300 is done
# 2400 is done
# 2500 is done
# 2600 is done
# 2700 is done
# 2800 is done
# 2900 is done
# 3000 is done
# 3100 is done
# 3200 is done
# 3300 is done
# 3400 is done
# 3500 is done
# 3600 is done
# 3700 is done
# 3800 is done
# 3900 is done
# 4000 is done
# 4100 is done
# 4200 is done
# 4300 is done
# 4400 is done
# 4500 is done
# 4600 is done
# 4700 is done
# 4800 is done
# 4900 is done
# 5000 is done
# 5100 is done
# 5200 is done
# 5300 is done
# 5400 is done
# 5500 is done
# 5600 is done
# 5700 is done
# 5800 is done
# 5900 is done
# 6000 is done
# 6100 is done
# 6200 is done
# 6300 is done
# 6400 is done
# 6500 is done
# 6600 is done
# 6700 is done
# 6800 is done
# 6900 is done
# 7000 is done
# 7100 is done
# 7200 is done
# 7300 is done
# 7400 is done
# 7500 is done
# 7600 is done
# 7700 is done
# 7800 is done
# 7900 is done
# 8000 is done
# 8100 is done
# 8200 is done
# 8300 is done
# 8400 is done
# 8500 is done
# 8600 is done
# 8700 is done
# 8800 is done
# 8900 is done
# 9000 is done
# 9100 is done
# 9200 is done
# 9300 is done
# 9400 is done
# 9500 is done
# 9600 is done
# 9700 is done
# 9800 is done
# 9900 is done
# 10000 is done
# 10100 is done
# 10200 is done
# 10300 is done
# 10400 is done
# 10500 is done
# 10600 is done
# 10700 is done
# 10800 is done
# 10900 is done
# 11000 is done
# 11100 is done
# 11200 is done
# 11300 is done
# 11400 is done
# 11500 is done
# 11600 is done
# 11700 is done
# 11800 is done
# 11900 is done
# 12000 is done
# 12100 is done
# 12200 is done
# 12300 is done
# 12400 is done
# 12500 is done
# 12600 is done
# 12700 is done
# 12800 is done
# 12900 is done
# 13000 is done
# 13100 is done
# 13200 is done
# 13300 is done
# 13400 is done
# 13500 is done
# 13600 is done
# 13700 is done
# 13800 is done
# 13900 is done
# 14000 is done
# 14100 is done
# 14200 is done
# 14300 is done
# 14400 is done
# 14500 is done
# 14600 is done
# 14700 is done
# 14800 is done
# 14900 is done
# 15000 is done
# 15100 is done
# 15200 is done
# 15300 is done
# 15400 is done
# 15500 is done
# 15600 is done
# 15700 is done
# 15800 is done
# 15900 is done
# 16000 is done
# 16100 is done
# 16200 is done
# 16300 is done
# 16400 is done
# 16500 is done
# 16600 is done
# 16700 is done
# 16800 is done
# 16900 is done
# 17000 is done
# 17100 is done
# 17200 is done
# 17300 is done
# 17400 is done
# 17500 is done
# 17600 is done
# 17700 is done
# 17800 is done
# 17900 is done
# 18000 is done
# 18100 is done
# 18200 is done
# 18300 is done
# 18400 is done
# 18500 is done
# 18600 is done
# 18700 is done
# 18800 is done
# 18900 is done
# 19000 is done
# 19100 is done
# 19200 is done
# 19300 is done
# 19400 is done
# 19500 is done
# 19600 is done
# 19700 is done
# 19800 is done
# 19900 is done
# 20000 is done
# 20100 is done
# 20200 is done
# 20300 is done
# 20400 is done
# 20500 is done
# 20600 is done
# 20700 is done
# 20800 is done
# 20900 is done
# 21000 is done
# 21100 is done
# 21200 is done
# 21300 is done
# 21400 is done
# 21500 is done
# 21600 is done
# 21700 is done
# 21800 is done
# 21900 is done
# 22000 is done
# 22100 is done
# 22200 is done
# 22300 is done
# 22400 is done
# 22500 is done
# 22600 is done
# 22700 is done
# 22800 is done
# 22900 is done
# 23000 is done
# 23100 is done
# 23200 is done
# 23300 is done
# 23400 is done
# 23500 is done
# 23600 is done
# 23700 is done
# 23800 is done
# 23900 is done
# 24000 is done
# 24100 is done
# 24200 is done
# 24300 is done
# 24400 is done
# 24500 is done
# 24600 is done
# 24700 is done
# 24800 is done
# 24900 is done
# 25000 is done
# 25100 is done
# 25200 is done
# 25300 is done
# 25400 is done
# 25500 is done
# 25600 is done
# 25700 is done
# 25800 is done
# 25900 is done
# 26000 is done
# 26100 is done
# 26200 is done
# 26300 is done
# 26400 is done
# 26500 is done
# 26600 is done
# 26700 is done
# 26800 is done
# 26900 is done
# 27000 is done
# 27100 is done
# 27200 is done
# 27300 is done
# 27400 is done
# 27500 is done
# 27600 is done
# 27700 is done
# 27800 is done
# 27900 is done
# 28000 is done
# 28100 is done
# 28200 is done
# 28300 is done
# 28400 is done
# 28500 is done
# 28600 is done
# 28700 is done
# 28800 is done
# 28900 is done
# 29000 is done
# 29100 is done
# 29200 is done
# 29300 is done
# 29400 is done
# 29500 is done
# 29600 is done
# 29700 is done
# 29800 is done
# 29900 is done
# 30000 is done
# 30100 is done
# 30200 is done
# 30300 is done
# 30400 is done
# 30500 is done
# 30600 is done
# 30700 is done
# 30800 is done
# 30900 is done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-fd2325a1fb10> in <module>
#       3     if i % 100 == 0 :
#       4         print(i,"is done")
# ----> 5     X_train['designation_cleaned'][i] = raw_to_tokens(X_train['designation'][i] ,spacy_nlp)
#
# <ipython-input-9-744cfc1c347c> in raw_to_tokens(raw_string, spacy_nlp)
#       7
#       8     # Write code to tokenize
# ----> 9     spacy_tokens = spacy_nlp(string)
#      10
#      11     # Write code to remove punctuation tokens and create string tokens
#
# /opt/anaconda3/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     433             if not hasattr(proc, "__call__"):
#     434                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 435             doc = proc(doc, **component_cfg.get(name, {}))
#     436             if doc is None:
#     437                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.Tagger.predict()
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/api.py in predict(seqs_in)
#     308     def predict(seqs_in):
#     309         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
# --> 310         X = layer(layer.ops.flatten(seqs_in, pad=pad))
#     311         return layer.ops.unflatten(X, lengths, pad=pad)
#     312
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in predict(self, X)
#      38     def predict(self, X):
#      39         for layer in self._layers:
# ---> 40             X = layer(X)
#      41         return X
#      42
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/model.py in __call__(self, x)
#     167             Must match expected shape
#     168         """
# --> 169         return self.predict(x)
#     170
#     171     def pipe(self, stream, batch_size=128):
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/model.py in predict(self, X)
#     131
#     132     def predict(self, X):
# --> 133         y, _ = self.begin_update(X, drop=None)
#     134         return y
#     135
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/api.py in uniqued_fwd(X, drop)
#     377         )
#     378         X_uniq = layer.ops.xp.ascontiguousarray(X[ind])
# --> 379         Y_uniq, bp_Y_uniq = layer.begin_update(X_uniq, drop=drop)
#     380         Y = Y_uniq[inv].reshape((X.shape[0],) + Y_uniq.shape[1:])
#     381
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/feed_forward.py in begin_update(self, X, drop)
#      44         callbacks = []
#      45         for layer in self._layers:
# ---> 46             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      47             callbacks.append(inc_layer_grad)
#      48
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      58     def begin_update(self, X, drop=0.0):
#      59         if self.child is not None:
# ---> 60             X, backprop_child = self.child.begin_update(X, drop=0.0)
#      61         else:
#      62             backprop_child = None
#
# /opt/anaconda3/lib/python3.7/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      74         if drop is not None:
#      75             drop *= self.drop_factor
# ---> 76         output__boc = self.ops.gemm(X__bi, W, trans2=True)
#      77         output__boc += self.b.reshape((self.nO * self.nP,))
#      78         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# KeyboardInterrupt:

# %%
X_train.head(30)

# %%
Y_train.head()
# Out:
#    Unnamed: 0  prdtypecode
# 0           0           10
# 1           1         2280
# 2           2           50
# 3           3         1280
# 4           4         2705
